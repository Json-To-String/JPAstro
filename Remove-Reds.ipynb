# %%
# Python program to identify
#color in images
  
# Importing the libraries OpenCV and numpy
import cv2
# import numpy as np
import os
import glob
# import matplotlib.pyplot as plt
# from matplotlib import image as mpimg
# import pathlib
# %matplotlib inline

# %%
# baseDir = 'rotations-png'
# rotDir = os.path.join(baseDir, 'train', '*')
# # for x in glob.glob(rotDir):
# #     print(x)
# imgs = glob.glob(rotDir)
# n = np.random.randint(len(imgs))
# testImgPath = imgs[n]
# plt.title(testImgPath.split('\\')[-1])
# plt.xlabel("X pixel scaling")
# plt.ylabel("Y pixels scaling")
# image = mpimg.imread(testImgPath)
# plt.imshow(image)
# plt.show()

# %%
# ######## K-means clustering ########
# Z = image.reshape((-1,3))

# # convert to np.float32
# Z = np.float32(Z)

# # define criteria, number of clusters(K) and apply kmeans()
# criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
# K = 10
# ret,label,center=cv2.kmeans(Z,K,None,criteria,10,cv2.KMEANS_RANDOM_CENTERS)

# # Now convert back into uint8, and make original image
# center = np.uint8(center)
# res = center[label.flatten()]
# res2 = res.reshape((image.shape))

# # cv2.imshow('res2',res2)
# # cv2.waitKey(0)
# # cv2.destroyAllWindows()

# plt.imshow(res2)

# %%
# img0 = test_generator[2][0]
# plt.figure()
# plt.imshow(img0)
# plt.show()
import glob
from matplotlib import image as mpimg
# %matplotlib inline

baseDir = 'rotations-png'
rotDir = os.path.join(baseDir, 'train', '*')
imgs = glob.glob(rotDir)


# n = np.random.randint(len(imgs))

# lower boundary RED color range values; Hue (0 - 10)
lower1 = np.array([0, 80, 20])
upper1 = np.array([10, 255, 255])
 
# upper boundary RED color range values; Hue (160 - 180)
lower2 = np.array([160, 100, 20])
upper2 = np.array([179, 255, 255])

counter = 0
for n in range(len(imgs)):
    testImgPath = imgs[n]
    image = cv2.imread(testImgPath)
#     print(testImgPath)
    result = image.copy()
    image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    
    lower_mask = cv2.inRange(image, lower1, upper1)
    upper_mask = cv2.inRange(image, lower2, upper2)
    full_mask = lower_mask + upper_mask;

    result = cv2.bitwise_and(result, result, mask=full_mask)
    dim = np.shape(full_mask)[0] 
    counts = np.count_nonzero(full_mask)
#     print(counts)
#     print(dim**2)
    percent = 100*counts/dim**2
    subtitle_string = f'{percent}% of the image is red'
    filename = testImgPath.split('\\')[-1]
#     print(f'{filename}, {subtitle_string}')
    if percent > 50.0:
        counter += 1
#         print('To be removed')
    else:
        pass
    
    
# plt.title(testImgPath.split('\\')[-1])
# plt.xlabel("X pixel scaling")
# plt.ylabel("Y pixels scaling")
# image = mpimg.imread(testImgPath)
# plt.imshow(image)
# plt.show()

# # here's a test red image
# redImg = 'sdss_ra=49.895_dec=41.3918_rot90_label=0.png'
# testImgPath = os.path.join(baseDir, 'train', redImg)

# cv2.imshow("Original", image)

# # Get red color
# red = np.uint8([[[0, 0, 255]]])
  
# Convert red color to red HSV
# hsv_red = cv2.cvtColor(red, cv2.COLOR_BGR2HSV)

# # Resizing the image
# image = cv2.resize(image, (500, 500))
# # cv2.imshow('image', image)
# cv2.imshow('mask', full_mask)
# cv2.imshow('result', result)

# plt.suptitle(filename)
# plt.title(subtitle_string, fontsize=10)
# plt.xlabel("X pixel scaling")
# plt.ylabel("Y pixels scaling")
# image = mpimg.imread(testImgPath)
# plt.imshow(image)
# # image[:,:,::-1]
# plt.show()


print(counter)
# Out:
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# To be removed
# 360

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is B40E-8C3D
#
#  Directory of C:\Users\Jason\Documents\SJSU\JPAstro
#
# 07/13/2023  12:12 AM    <DIR>          .
# 07/13/2023  12:12 AM    <DIR>          ..
# 10/13/2022  04:50 PM                15 .gitignore
# 07/03/2023  01:51 AM    <DIR>          .ipynb_checkpoints
# 01/10/2023  01:22 AM            18,944 adv-gal-exercise1.xls
# 10/06/2022  01:50 PM            42,509 Astro Introbook.ipynb
# 03/17/2023  02:52 AM    <DIR>          augmentedData
# 07/13/2023  12:12 AM            34,513 confusion-matrix_init-lr=0.075_decay-rate=0.99_offrots.png
# 10/12/2022  03:40 PM             2,450 flake.lock
# 10/12/2022  03:40 PM               713 flake.nix
# 05/13/2023  11:40 AM                66 getImages.sh
# 04/12/2023  01:37 AM    <DIR>          image256
# 10/06/2022  01:50 PM    <DIR>          IntroImages
# 06/03/2023  08:08 PM                35 login.sh
# 06/09/2023  11:12 AM    <DIR>          logs
# 04/07/2023  01:59 AM    <DIR>          model_checkpoint
# 01/10/2023  01:27 AM                 0 path
# 10/06/2022  01:50 PM         1,554,981 PCC_cat.txt
# 07/07/2023  05:10 PM           281,792 Perseus Cluster Populate Dataset.ipynb
# 10/12/2022  03:40 PM            82,533 Perseus Cluster.ipynb.old
# 06/19/2023  10:54 PM         1,976,246 Perseus Kaggle Ex.ipynb
# 04/10/2023  02:30 AM            18,807 Perseus Kaggle TfDataset method.ipynb
# 01/10/2023  01:22 AM            48,971 Perseus TensorFlow.ipynb
# 06/19/2023  11:05 PM            22,801 PerseusKaggleEx.py
# 07/13/2023  12:12 AM            31,112 perseusResNet50.ipynb
# 06/19/2023  11:05 PM             1,304 populateDataset.py
# 07/12/2023  04:17 PM            14,896 Remove-Reds.ipynb
# 06/30/2023  01:28 PM            22,850 resNet50Gal.py
# 01/10/2023  01:22 AM             1,223 results.csv
# 06/19/2023  10:54 PM            23,156 rotate-output.png
# 06/19/2023  11:05 PM    <DIR>          rotations
# 06/19/2023  11:05 PM    <DIR>          rotations01
# 04/21/2023  08:02 PM    <DIR>          rotations360
# 06/19/2023  11:05 PM    <DIR>          rotations-png
# 06/19/2023  11:05 PM    <DIR>          SDSS1
# 06/19/2023  11:05 PM    <DIR>          SDSS400
# 06/19/2023  11:05 PM    <DIR>          SDSS-png
# 01/10/2023  01:22 AM             1,871 Skyserver_Radial9_28_2022 7_00_56 AM.csv
# 10/06/2022  01:50 PM            67,136 specutils_demo.ipynb
# 10/17/2022  06:25 PM             6,894 tensorflow_gpu.yaml
# 01/10/2023  01:22 AM    <DIR>          test
# 07/12/2023  08:56 PM           112,434 train-report_init-lr=0.075_decay-rate=0.99_offrots.png
# 06/19/2023  11:05 PM    <DIR>          train-results
# 06/19/2023  11:05 PM    <DIR>          train-results-mix-fix
# 01/10/2023  01:22 AM    <DIR>          waittest
# 10/06/2022  01:50 PM         4,763,570 Wittmann_etal19.pdf
#               27 File(s)      9,131,822 bytes
#               19 Dir(s)  30,565,314,560 bytes free

# %%
import os
import glob
# want to clean /rotations-png/test and /rotations-png/train/
imgDirectory = 'rotations-png'
testPath = os.path.join(imgDirectory,'test','*')
testImgs = glob.glob(testPath)
trainPath = os.path.join(imgDirectory,'train','*')
trainImgs = glob.glob(trainPath)

# testImgs = glob.glob(testDir)
for x, y in zip(testImgs, trainImgs):
    print(f'Remove {x} and {y}')
    os.remove(x)
    os.remove(y)

# %%
trainPath
# Out:
# 'rotations-png\\train\\*'
