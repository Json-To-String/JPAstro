# %%
import pandas as pd

# %%
df0 = pd.read_csv('new_set1000.csv')

# %%
flags = df0['Column1']
tags = ['GALAXY']*len(flags)
df0['tags'] = tags
# df0

# %%
df0.loc[0, 'tags']
# Out:
# 'GALAXY'

# %%
# list_lists = []
# for x in flags:
#     list_lists.append(x.split(' '))
    
# # set.intersection(*[set(list) for list in list_lists])
# list_lists

# %%
# set.intersection(*map(set, list_lists))

# %%
reject_csv = pd.read_csv('Reject Stars - twoColumn.csv')
reject_csv
# Out:
#     Star                objID         ra        dec  \
# 0    NaN  1237661121850901163  48.999980  41.287510
# 1    NaN  1237661083199078716  49.238530  41.356745
# 2    NaN  1237661122387837316  49.303027  41.483379
# 3    NaN  1237661059574203088  49.670447  41.737503
# 4    NaN  1237661060111007994  49.709298  42.151482
# 5    NaN  1237661055818465980  49.723335  41.987172
# 6    NaN  1237661060111008401  49.864958  42.206252
# 7    NaN  1237670458048512961  49.942790  41.879515
# 8    NaN  1237661060111204440  50.216443  41.971605
# 9    NaN  1237661059574530110  50.378387  41.358666
# 10   NaN  1237661059574595780  50.864339  41.710322
#
#                                                 Flags  \
# 0   DEBLEND_DEGENERATE BAD_MOVING_FIT_CHILD PEAKS_...
# 1   DEBLENDED_AT_EDGE STATIONARY BINNED1 SUBTRACTE...
# 2   TOO_FEW_GOOD_DETECTIONS PSF_FLUX_INTERP DEBLEN...
# 3   DEBLENDED_AT_EDGE BAD_MOVING_FIT MOVED BINNED1...
# 4   PSF_FLUX_INTERP DEBLENDED_AT_EDGE STATIONARY B...
# 5   DEBLENDED_AT_EDGE STATIONARY BINNED1 SUBTRACTE...
# 6   TOO_FEW_GOOD_DETECTIONS PSF_FLUX_INTERP DEBLEN...
# 7   DEBLENDED_AT_EDGE STATIONARY MOVED BINNED1 INT...
# 8   MAYBE_CR TOO_FEW_GOOD_DETECTIONS PSF_FLUX_INTE...
# 9   MAYBE_CR DEBLEND_NOPEAK DEBLENDED_AT_EDGE BAD_...
# 10  PSF_FLUX_INTERP DEBLEND_NOPEAK DEBLENDED_AT_ED...
#
#                                                 notes  Galaxy  \
# 0                                   clearly two stars     NaN
# 1                                                 NaN     NaN
# 2   artifact from bright star nearby https://skyse...     NaN
# 3                                                 NaN     NaN
# 4                                                 NaN     NaN
# 5                                                 NaN     NaN
# 6                                                 NaN     NaN
# 7                                                 NaN     NaN
# 8                                                 NaN     NaN
# 9                                                 NaN     NaN
# 10                                                NaN     NaN
#
#                 objID.1       ra.1      dec.1  \
# 0   1237661083199275572  49.693181  41.031127
# 1   1237670960021111926  49.410488  41.011425
# 2   1237661083199145348  49.334788  41.258372
# 3   1237661122387903518  49.518370  41.369743
# 4   1237661059574203219  49.647607  41.667027
# 5   1237661122388034195  49.745417  41.320873
# 6   1237661060111009021  49.760077  42.122564
# 7   1237661059574268657  49.785213  41.581111
# 8   1237661083199275822  49.786257  41.126914
# 9   1237661122388099272  49.904114  41.171023
# 10  1237670960021571131  50.037643  41.817285
#
#                                               Flags.1  \
# 0   DEBLENDED_AT_EDGE STATIONARY BINNED1 INTERP CO...
# 1   DEBLENDED_AT_EDGE STATIONARY BINNED1 INTERP CO...
# 2   PSF_FLUX_INTERP DEBLENDED_AT_EDGE STATIONARY B...
# 3   PSF_FLUX_INTERP DEBLENDED_AT_EDGE INTERP_CENTE...
# 4   PSF_FLUX_INTERP DEBLENDED_AT_EDGE BAD_MOVING_F...
# 5   DEBLENDED_AT_EDGE STATIONARY BINNED1 INTERP CO...
# 6                     DEBLENDED_AT_EDGE BINNED1 CHILD
# 7   DEBLENDED_AT_EDGE STATIONARY BINNED1 INTERP CO...
# 8   DEBLENDED_AT_EDGE STATIONARY BAD_MOVING_FIT BI...
# 9   DEBLENDED_AT_EDGE STATIONARY BINNED1 SATURATED...
# 10  PSF_FLUX_INTERP DEBLENDED_AT_EDGE STATIONARY B...
#
#                                               notes.1
# 0   https://skyserver.sdss.org/dr16/en/tools/explo...
# 1   https://skyserver.sdss.org/dr16/en/tools/explo...
# 2   https://skyserver.sdss.org/dr16/en/tools/explo...
# 3   https://skyserver.sdss.org/dr16/en/tools/explo...
# 4   https://skyserver.sdss.org/dr16/en/tools/explo...
# 5   https://skyserver.sdss.org/dr16/en/tools/explo...
# 6   https://skyserver.sdss.org/dr16/en/tools/explo...
# 7   https://skyserver.sdss.org/dr16/en/tools/explo...
# 8   https://skyserver.sdss.org/dr16/en/tools/explo...
# 9   https://skyserver.sdss.org/dr16/en/tools/explo...
# 10  https://skyserver.sdss.org/dr16/en/tools/explo...

# %%
starFlags = reject_csv['Flags']
galFlags = reject_csv['Flags.1']
starID = reject_csv['objID']

# starFlags = starFlags.to_list()
starDf = reject_csv[['objID', 'Flags']].copy()
starDf
# Out:
#                   objID                                              Flags
# 0   1237661121850901163  DEBLEND_DEGENERATE BAD_MOVING_FIT_CHILD PEAKS_...
# 1   1237661083199078716  DEBLENDED_AT_EDGE STATIONARY BINNED1 SUBTRACTE...
# 2   1237661122387837316  TOO_FEW_GOOD_DETECTIONS PSF_FLUX_INTERP DEBLEN...
# 3   1237661059574203088  DEBLENDED_AT_EDGE BAD_MOVING_FIT MOVED BINNED1...
# 4   1237661060111007994  PSF_FLUX_INTERP DEBLENDED_AT_EDGE STATIONARY B...
# 5   1237661055818465980  DEBLENDED_AT_EDGE STATIONARY BINNED1 SUBTRACTE...
# 6   1237661060111008401  TOO_FEW_GOOD_DETECTIONS PSF_FLUX_INTERP DEBLEN...
# 7   1237670458048512961  DEBLENDED_AT_EDGE STATIONARY MOVED BINNED1 INT...
# 8   1237661060111204440  MAYBE_CR TOO_FEW_GOOD_DETECTIONS PSF_FLUX_INTE...
# 9   1237661059574530110  MAYBE_CR DEBLEND_NOPEAK DEBLENDED_AT_EDGE BAD_...
# 10  1237661059574595780  PSF_FLUX_INTERP DEBLEND_NOPEAK DEBLENDED_AT_ED...

# %%
df_melt = pd.melt(starDf)

df_melt
unique_star_flags = set()

for objflags in (starFlags.to_list()):
    objflags = objflags.split(' ')
    for flag in objflags:
        if flag not in unique_star_flags:
            unique_star_flags.add(flag)
unique_star_flags
# Out:
# {'BAD_MOVING_FIT',
#  'BAD_MOVING_FIT_CHILD',
#  'BINNED1',
#  'BLENDED',
#  'CHILD',
#  'COSMIC_RAY',
#  'DEBLENDED_AS_PSF',
#  'DEBLENDED_AT_EDGE',
#  'DEBLEND_DEGENERATE',
#  'DEBLEND_NOPEAK',
#  'DEBLEND_PRUNED',
#  'EDGE',
#  'INTERP',
#  'INTERP_CENTER',
#  'MANYPETRO',
#  'MAYBE_CR',
#  'MOVED',
#  'NODEBLEND',
#  'NODEBLEND_MOVING',
#  'NOTCHECKED',
#  'PEAKS_TOO_CLOSE',
#  'PSF_FLUX_INTERP',
#  'SATURATED',
#  'SATUR_CENTER',
#  'STATIONARY',
#  'SUBTRACTED',
#  'TOO_FEW_GOOD_DETECTIONS'}

# %%
starDf
# Out:
#                   objID                                              Flags
# 0   1237661121850901163  DEBLEND_DEGENERATE BAD_MOVING_FIT_CHILD PEAKS_...
# 1   1237661083199078716  DEBLENDED_AT_EDGE STATIONARY BINNED1 SUBTRACTE...
# 2   1237661122387837316  TOO_FEW_GOOD_DETECTIONS PSF_FLUX_INTERP DEBLEN...
# 3   1237661059574203088  DEBLENDED_AT_EDGE BAD_MOVING_FIT MOVED BINNED1...
# 4   1237661060111007994  PSF_FLUX_INTERP DEBLENDED_AT_EDGE STATIONARY B...
# 5   1237661055818465980  DEBLENDED_AT_EDGE STATIONARY BINNED1 SUBTRACTE...
# 6   1237661060111008401  TOO_FEW_GOOD_DETECTIONS PSF_FLUX_INTERP DEBLEN...
# 7   1237670458048512961  DEBLENDED_AT_EDGE STATIONARY MOVED BINNED1 INT...
# 8   1237661060111204440  MAYBE_CR TOO_FEW_GOOD_DETECTIONS PSF_FLUX_INTE...
# 9   1237661059574530110  MAYBE_CR DEBLEND_NOPEAK DEBLENDED_AT_EDGE BAD_...
# 10  1237661059574595780  PSF_FLUX_INTERP DEBLEND_NOPEAK DEBLENDED_AT_ED...

# %%
flagDf = pd.DataFrame(columns = list(unique_star_flags)) 
# flagDf = flagDf.append(new_row, ignore_index=True)
flagDf
# Out:
# Empty DataFrame
# Columns: [CHILD, PSF_FLUX_INTERP, MOVED, TOO_FEW_GOOD_DETECTIONS, DEBLEND_NOPEAK, NODEBLEND_MOVING, DEBLENDED_AT_EDGE, DEBLENDED_AS_PSF, SATUR_CENTER, PEAKS_TOO_CLOSE, DEBLEND_PRUNED, SUBTRACTED, EDGE, MAYBE_CR, DEBLEND_DEGENERATE, NOTCHECKED, BAD_MOVING_FIT_CHILD, STATIONARY, COSMIC_RAY, MANYPETRO, INTERP, BLENDED, BAD_MOVING_FIT, BINNED1, SATURATED, NODEBLEND, INTERP_CENTER]
# Index: []
#
# [0 rows x 27 columns]

# %%
x = set(starDf['Flags'][0].split(' '))

x.intersection(unique_star_flags)
# Out:
# {'BAD_MOVING_FIT',
#  'BAD_MOVING_FIT_CHILD',
#  'BINNED1',
#  'BLENDED',
#  'DEBLEND_DEGENERATE',
#  'DEBLEND_PRUNED',
#  'MANYPETRO',
#  'MOVED',
#  'NODEBLEND',
#  'NODEBLEND_MOVING',
#  'PEAKS_TOO_CLOSE'}

# %%
unique_star_flags
# Out:
# {'BAD_MOVING_FIT',
#  'BAD_MOVING_FIT_CHILD',
#  'BINNED1',
#  'BLENDED',
#  'CHILD',
#  'COSMIC_RAY',
#  'DEBLENDED_AS_PSF',
#  'DEBLENDED_AT_EDGE',
#  'DEBLEND_DEGENERATE',
#  'DEBLEND_NOPEAK',
#  'DEBLEND_PRUNED',
#  'EDGE',
#  'INTERP',
#  'INTERP_CENTER',
#  'MANYPETRO',
#  'MAYBE_CR',
#  'MOVED',
#  'NODEBLEND',
#  'NODEBLEND_MOVING',
#  'NOTCHECKED',
#  'PEAKS_TOO_CLOSE',
#  'PSF_FLUX_INTERP',
#  'SATURATED',
#  'SATUR_CENTER',
#  'STATIONARY',
#  'SUBTRACTED',
#  'TOO_FEW_GOOD_DETECTIONS'}

# %%
# df_melt = reject_csv.assign(flags=reject_csv['Flags'].to_list().str.split(' '))

# %%
reject_stars = pd.concat([starDf, flagDf])
pd.options.display.float_format = '{:.0f}'.format # suppress conversion to scientific notation 
reject_stars
# Out:
#                  objID                                              Flags  \
# 0  1237661121850901248  DEBLEND_DEGENERATE BAD_MOVING_FIT_CHILD PEAKS_...
# 1  1237661083199078656  DEBLENDED_AT_EDGE STATIONARY BINNED1 SUBTRACTE...
# 2  1237661122387837440  TOO_FEW_GOOD_DETECTIONS PSF_FLUX_INTERP DEBLEN...
# 3  1237661059574203136  DEBLENDED_AT_EDGE BAD_MOVING_FIT MOVED BINNED1...
# 4  1237661060111008000  PSF_FLUX_INTERP DEBLENDED_AT_EDGE STATIONARY B...
# 5  1237661055818466048  DEBLENDED_AT_EDGE STATIONARY BINNED1 SUBTRACTE...
# 6  1237661060111008512  TOO_FEW_GOOD_DETECTIONS PSF_FLUX_INTERP DEBLEN...
# 7  1237670458048513024  DEBLENDED_AT_EDGE STATIONARY MOVED BINNED1 INT...
# 8  1237661060111204352  MAYBE_CR TOO_FEW_GOOD_DETECTIONS PSF_FLUX_INTE...
# 9  1237661059574530048  MAYBE_CR DEBLEND_NOPEAK DEBLENDED_AT_EDGE BAD_...
# 10 1237661059574595840  PSF_FLUX_INTERP DEBLEND_NOPEAK DEBLENDED_AT_ED...
#
#    CHILD PSF_FLUX_INTERP MOVED TOO_FEW_GOOD_DETECTIONS DEBLEND_NOPEAK  \
# 0    NaN             NaN   NaN                     NaN            NaN
# 1    NaN             NaN   NaN                     NaN            NaN
# 2    NaN             NaN   NaN                     NaN            NaN
# 3    NaN             NaN   NaN                     NaN            NaN
# 4    NaN             NaN   NaN                     NaN            NaN
# 5    NaN             NaN   NaN                     NaN            NaN
# 6    NaN             NaN   NaN                     NaN            NaN
# 7    NaN             NaN   NaN                     NaN            NaN
# 8    NaN             NaN   NaN                     NaN            NaN
# 9    NaN             NaN   NaN                     NaN            NaN
# 10   NaN             NaN   NaN                     NaN            NaN
#
#    NODEBLEND_MOVING DEBLENDED_AT_EDGE DEBLENDED_AS_PSF  ... STATIONARY  \
# 0               NaN               NaN              NaN  ...        NaN
# 1               NaN               NaN              NaN  ...        NaN
# 2               NaN               NaN              NaN  ...        NaN
# 3               NaN               NaN              NaN  ...        NaN
# 4               NaN               NaN              NaN  ...        NaN
# 5               NaN               NaN              NaN  ...        NaN
# 6               NaN               NaN              NaN  ...        NaN
# 7               NaN               NaN              NaN  ...        NaN
# 8               NaN               NaN              NaN  ...        NaN
# 9               NaN               NaN              NaN  ...        NaN
# 10              NaN               NaN              NaN  ...        NaN
#
#    COSMIC_RAY MANYPETRO INTERP BLENDED BAD_MOVING_FIT BINNED1 SATURATED  \
# 0         NaN       NaN    NaN     NaN            NaN     NaN       NaN
# 1         NaN       NaN    NaN     NaN            NaN     NaN       NaN
# 2         NaN       NaN    NaN     NaN            NaN     NaN       NaN
# 3         NaN       NaN    NaN     NaN            NaN     NaN       NaN
# 4         NaN       NaN    NaN     NaN            NaN     NaN       NaN
# 5         NaN       NaN    NaN     NaN            NaN     NaN       NaN
# 6         NaN       NaN    NaN     NaN            NaN     NaN       NaN
# 7         NaN       NaN    NaN     NaN            NaN     NaN       NaN
# 8         NaN       NaN    NaN     NaN            NaN     NaN       NaN
# 9         NaN       NaN    NaN     NaN            NaN     NaN       NaN
# 10        NaN       NaN    NaN     NaN            NaN     NaN       NaN
#
#    NODEBLEND INTERP_CENTER
# 0        NaN           NaN
# 1        NaN           NaN
# 2        NaN           NaN
# 3        NaN           NaN
# 4        NaN           NaN
# 5        NaN           NaN
# 6        NaN           NaN
# 7        NaN           NaN
# 8        NaN           NaN
# 9        NaN           NaN
# 10       NaN           NaN
#
# [11 rows x 29 columns]

# %%
flagHits = list()
objects = reject_stars['objID'].to_list()
# for ind, x in enumerate(unique_star_flags):
#     print(x)
rejectFlags = reject_stars['Flags'].to_list()
# Out:
# ['DEBLEND_DEGENERATE BAD_MOVING_FIT_CHILD PEAKS_TOO_CLOSE BAD_MOVING_FIT NODEBLEND_MOVING MOVED BINNED1 DEBLEND_PRUNED MANYPETRO NODEBLEND BLENDED',
#  'DEBLENDED_AT_EDGE STATIONARY BINNED1 SUBTRACTED NOTCHECKED SATURATED INTERP COSMIC_RAY MANYPETRO CHILD EDGE',
#  'TOO_FEW_GOOD_DETECTIONS PSF_FLUX_INTERP DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY BINNED1 DEBLENDED_AS_PSF SATURATED INTERP COSMIC_RAY CHILD',
#  'DEBLENDED_AT_EDGE BAD_MOVING_FIT MOVED BINNED1 SATURATED INTERP CHILD',
#  'PSF_FLUX_INTERP DEBLENDED_AT_EDGE STATIONARY BINNED1 SATURATED INTERP COSMIC_RAY MANYPETRO CHILD',
#  'DEBLENDED_AT_EDGE STATIONARY BINNED1 SUBTRACTED SATURATED INTERP COSMIC_RAY MANYPETRO CHILD',
#  'TOO_FEW_GOOD_DETECTIONS PSF_FLUX_INTERP DEBLEND_NOPEAK DEBLENDED_AT_EDGE INTERP_CENTER SATUR_CENTER BINNED1 SUBTRACTED SATURATED INTERP COSMIC_RAY CHILD',
#  'DEBLENDED_AT_EDGE STATIONARY MOVED BINNED1 INTERP COSMIC_RAY CHILD',
#  'MAYBE_CR TOO_FEW_GOOD_DETECTIONS PSF_FLUX_INTERP DEBLEND_NOPEAK DEBLENDED_AT_EDGE INTERP_CENTER SATUR_CENTER BINNED1 SUBTRACTED SATURATED INTERP COSMIC_RAY CHILD',
#  'MAYBE_CR DEBLEND_NOPEAK DEBLENDED_AT_EDGE BAD_MOVING_FIT BINNED1 NOTCHECKED INTERP COSMIC_RAY MANYPETRO CHILD EDGE',
#  'PSF_FLUX_INTERP DEBLEND_NOPEAK DEBLENDED_AT_EDGE BAD_MOVING_FIT BINNED1 SUBTRACTED NOTCHECKED SATURATED INTERP COSMIC_RAY NODEBLEND CHILD BLENDED EDGE']

# %%
if reject_stars.columns[2].casefold() in rejectFlags[0].split(' '):
    print('Here')
else:
    print('Not here')
# Out:
# Not here

# %%
rejectFlags[0].split(' ')
# Out:
# ['DEBLEND_DEGENERATE',
#  'BAD_MOVING_FIT_CHILD',
#  'PEAKS_TOO_CLOSE',
#  'BAD_MOVING_FIT',
#  'NODEBLEND_MOVING',
#  'MOVED',
#  'BINNED1',
#  'DEBLEND_PRUNED',
#  'MANYPETRO',
#  'NODEBLEND',
#  'BLENDED']
