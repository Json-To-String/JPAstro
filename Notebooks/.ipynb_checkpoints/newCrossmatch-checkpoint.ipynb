# %%
import numpy as np
import pandas as pd
import SciServer.CasJobs as CasJobs # query with CasJobs, the primary database for the SDSS
import SciServer.SkyServer as SkyServer # show individual objects through SkyServer
import SciServer.SciDrive
import warnings
from PIL import Image

warnings.filterwarnings('ignore')

# %%
pwd
# Out:
# 'C:\\Users\\Jason\\Documents\\SJSU\\JPAstro'

# %%
SH_MDG = pd.read_csv('Sheets\SH_MDG.csv')
# SH_MDG

# %%
crossmatchQuery = '''CREATE TABLE #upload ( up_id int, up_ra float, up_dec float ) 
INSERT INTO #upload values ( 1, 49.43464, 40.87648),( 2, 50.71059, 40.90011),( 3, 50.43778, 40.96237),( 4, 50.55783, 40.95394),( 5, 50.27557, 40.97107),( 6, 49.08633, 40.97127),( 7, 50.33284, 40.99509),( 8, 50.01600, 41.05777),( 9, 50.52619, 41.08242),( 10, 49.26452, 41.09188),( 11, 49.54948, 41.23287),( 12, 49.81257, 41.23137),( 13, 50.71703, 41.24594),( 14, 49.71770, 41.26755),( 15, 50.34345, 41.27714),( 16, 49.61810, 41.28606),( 17, 49.42728, 41.32309),( 18, 48.92604, 41.31836),( 19, 50.14164, 41.37964),( 20, 49.78269, 41.41263),( 21, 50.33074, 41.41562),( 22, 49.21440, 41.45938),( 23, 50.06715, 41.48258),( 24, 50.34479, 41.50313),( 25, 49.01468, 41.52288),( 26, 49.51195, 41.51297),( 27, 50.28064, 41.53824),( 28, 50.47216, 41.56143),( 29, 50.49371, 41.57921),( 30, 49.42844, 41.59988),( 31, 49.86271, 41.60818),( 32, 49.39353, 41.62147),( 33, 49.79257, 41.67811),( 34, 50.49710, 41.78499),( 35, 49.48984, 41.77585),( 36, 50.63848, 41.79206),( 37, 49.60997, 41.81874),( 38, 49.44231, 41.93492),( 39, 50.32299, 41.97126),( 40, 50.56341, 41.97293),( 41, 50.02595, 42.00451),( 42, 49.78714, 42.13901),( 43, 50.17779, 42.20089),( 44, 49.48429, 42.20973),( 45, 49.70962, 42.31499),( 46, 50.35571, 40.90381),( 47, 49.84918, 41.09801),( 48, 50.07848, 41.09704),( 49, 50.48358, 41.10194),( 50, 49.76534, 41.19418),( 51, 50.32510, 41.40939),( 52, 48.87942, 41.48487),( 53, 50.02964, 41.53824),( 54, 50.12943, 41.56757),( 55, 49.24521, 41.68621),( 56, 50.18575, 42.03045)
create table #x (up_id int,objID bigint)
INSERT INTO #x 
SELECT up_id, dbo.fGetNearestObjIdEq(up_ra,up_dec,0.5) as objId 
     FROM #upload WHERE dbo.fGetNearestObjIdEq(up_ra,up_dec,0.5) IS NOT NULL 
SELECT
p.objID, 
dbo.fPhotoTypeN(p.type) as type,
p.ra, p.dec,
p.modelMag_r, 
p.modelMag_u - p.modelMag_g as u_g, 
p.modelMag_g - p.modelMag_z as g_z, 
p.modelMag_g - p.modelMag_r as g_r, 
p.modelMag_g - p.modelMag_i as g_i, 
p.modelMag_r - p.modelMag_i as r_i, 
p.modelMag_r - p.modelMag_z as r_z, 
p.flags, dbo.fPhotoFlagsN(p.flags) as flag_text
FROM #upload u
JOIN #x x ON x.up_id = u.up_id
JOIN PhotoTag p ON p.objID = x.objID 
ORDER BY x.up_id
'''
crossDf = CasJobs.executeQuery(crossmatchQuery, "dr16")
# crossDf

# %%
outDir = 'Images\SH_MDG'
img_width, img_height = 200, 200
SkyServer_DataRelease = 'DR16'

# # if len(outDir) == len(radDf['objID']):
# if len(outDir) > 10:
#     print('Skipping populate')
# else:
#     for id, z, r, d in zip(crossDf['objID'], crossDf['z'], crossDf['ra'], crossDf['dec']):
#         img_array = SkyServer.getJpegImgCutout(ra=r, dec=d, width=img_width, height=img_height, scale=0.1, 
#                                      dataRelease=SkyServer_DataRelease)
#         # print(f'{id}-label={labeler(z)}')
#         # outPicTemplate = f'{id}-label={labeler(z)}.png'
#         outPicTemplate = f'{id}.png'
        
#         img0 = Image.fromarray(img_array, 'RGB')
#         img0.save(f'{outDir}/{outPicTemplate}')


for id, r, d in zip(crossDf['objID'], crossDf['ra'], crossDf['dec']):
    img_array = SkyServer.getJpegImgCutout(ra=r, dec=d, width=img_width, height=img_height, scale=0.1, 
                                 dataRelease=SkyServer_DataRelease)
    # print(f'{id}-label={labeler(z)}')
    # outPicTemplate = f'{id}-label={labeler(z)}.png'
    outPicTemplate = f'{id}.png'
    
    img0 = Image.fromarray(img_array, 'RGB')
    img0.save(f'{outDir}/{outPicTemplate}')

# %%
crossDf
# Out:
#                   objID    type         ra        dec  modelMag_r       u_g  \
# 0   1237661082662404973  GALAXY  49.434658  40.876480    17.06913  1.810234
# 1   1237661055282119523  GALAXY  50.710497  40.900186    20.92502  1.749641
# 2   1237661055282054357  GALAXY  50.437752  40.962316    18.14545  1.369568
# 3   1237661055282120491  GALAXY  50.557756  40.953899    17.30180  1.812160
# 4   1237661083199471946  GALAXY  50.275935  40.972246    18.07482  3.237286
# 5   1237661082662273421  GALAXY  49.086137  40.971285    17.97118  2.893913
# 6   1237661055282053207  GALAXY  50.332798  40.995054    18.14707  2.028221
# 7   1237661083199342924  GALAXY  50.015993  41.057654    18.05915  1.219753
# 8   1237661055282053546  GALAXY  50.527160  41.081803    16.69114  1.495518
# 9   1237670458048119587  GALAXY  49.264546  41.091962    18.66797  5.132727
# 10  1237661083199211267  GALAXY  49.549481  41.232865    18.35022  1.217857
# 11  1237661122388033900  GALAXY  49.812646  41.231299    18.42670  5.828825
# 12  1237661059574596877  GALAXY  50.717049  41.245984    17.91113  2.353449
# 13  1237661122388034216  GALAXY  49.717747  41.267558    17.35186  0.225946
# 14  1237661059574531312  GALAXY  50.343475  41.277186    18.06137  1.255127
# 15  1237661083199209883  GALAXY  49.618014  41.285945    18.64474  3.259039
# 16  1237661083199144423  GALAXY  49.427311  41.323124    17.73236  2.650261
# 17  1237661121850900980    STAR  48.927807  41.317545    16.43963  1.393778
# 18  1237661059574400634  GALAXY  50.141699  41.379626    18.62868  2.289833
# 19  1237661122387968435  GALAXY  49.782598  41.412733    17.87237  3.186100
# 20  1237661059574465125  GALAXY  50.330720  41.415648    17.91619  2.007191
# 49  0.099232  1.085514  0.777903 -0.307611 -0.986282    105656499442008
# 50  0.139948  0.115374  0.636683  0.521309  0.024574    105622104310032
# 51  1.703907 -0.179411 -0.033815  0.145596  1.883318    105622137868560
# 52  0.502682  0.344635  0.461782  0.117147  0.158047     35255507615760
# 53  1.341034  0.826649  1.204132  0.377483  0.514385    193583034532112
# 54  1.483976  0.808941  1.414742  0.605801  0.675036    246325232931088
# 55  1.369959  0.875164  1.421457  0.546293  0.494795    105622104310032
#
#                                             flag_text
# 0   DEBLENDED_AT_EDGE STATIONARY BINNED1 INTERP CO...
# 1   DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY BI...
# 2   PSF_FLUX_INTERP DEBLEND_NOPEAK DEBLENDED_AT_ED...
# 3   DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY MO...
# 4   DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY BI...
# 5   DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY BI...
# 6   DEBLENDED_AT_EDGE STATIONARY BINNED1 SATURATED...
# 7   PSF_FLUX_INTERP DEBLENDED_AT_EDGE STATIONARY M...
# 8   DEBLENDED_AT_EDGE STATIONARY BINNED1 INTERP CO...
# 9   DEBLENDED_AT_EDGE STATIONARY BINNED1 INTERP NO...
# 10  DEBLENDED_AT_EDGE STATIONARY MOVED BINNED1 INT...
# 11  DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY BI...
# 12  PSF_FLUX_INTERP DEBLEND_NOPEAK DEBLENDED_AT_ED...
# 13  MAYBE_CR DEBLEND_NOPEAK DEBLENDED_AT_EDGE STAT...
# 14  PSF_FLUX_INTERP DEBLEND_NOPEAK DEBLENDED_AT_ED...
# 15  DEBLENDED_AT_EDGE STATIONARY MOVED BINNED1 CHILD
# 16  DEBLENDED_AT_EDGE STATIONARY BINNED1 INTERP NO...
# 17  DEBLENDED_AT_EDGE STATIONARY MOVED BINNED1 INT...
# 18  PSF_FLUX_INTERP DEBLEND_NOPEAK DEBLENDED_AT_ED...
# 19  DEBLENDED_AT_EDGE STATIONARY BINNED1 INTERP CO...
# 20  PSF_FLUX_INTERP DEBLENDED_AT_EDGE INTERP_CENTE...
# 21  DEBLENDED_AT_EDGE BAD_MOVING_FIT BINNED1 SATUR...
# 22  DEBLENDED_AT_EDGE STATIONARY BINNED1 INTERP CO...
# 23  PSF_FLUX_INTERP DEBLEND_NOPEAK DEBLENDED_AT_ED...
# 24  DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY BI...
# 25  DEBLENDED_AT_EDGE STATIONARY BAD_MOVING_FIT BI...
# 26  DEBLENDED_AT_EDGE STATIONARY BAD_MOVING_FIT BI...
# 27  DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY MO...
# 28  PSF_FLUX_INTERP DEBLENDED_AT_EDGE STATIONARY M...
# 29  PSF_FLUX_INTERP DEBLENDED_AT_EDGE STATIONARY M...
# 30  PSF_FLUX_INTERP DEBLENDED_AT_EDGE STATIONARY B...
# 31  DEBLEND_DEGENERATE DEBLENDED_AT_EDGE STATIONAR...
# 32  PSF_FLUX_INTERP DEBLEND_NOPEAK DEBLENDED_AT_ED...
# 33  DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY MO...
# 34  DEBLENDED_AT_EDGE STATIONARY BINNED1 SATURATED...
# 35  PSF_FLUX_INTERP DEBLENDED_AT_EDGE STATIONARY B...
# 36  PSF_FLUX_INTERP DEBLENDED_AT_EDGE STATIONARY B...
# 37  DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY BI...
# 38  DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY BI...
# 39  DEBLENDED_AT_EDGE STATIONARY BINNED1 INTERP CO...
# 40  DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY BI...
# 41  PSF_FLUX_INTERP DEBLEND_NOPEAK DEBLENDED_AT_ED...
# 42  DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY BI...
# 43  DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY MO...
# 44  TOO_FEW_GOOD_DETECTIONS PSF_FLUX_INTERP DEBLEN...
# 45  TOO_FEW_GOOD_DETECTIONS DEBLEND_NOPEAK DEBLEND...
# 46  DEBLENDED_AT_EDGE BINNED1 DEBLENDED_AS_PSF SUB...
# 47  BAD_MOVING_FIT_CHILD PEAKS_TOO_CLOSE STATIONAR...
# 48  DEBLENDED_AT_EDGE STATIONARY BINNED1 DEBLENDED...
# 49  DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY BA...
# 50  DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY BI...
# 51  DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY BI...
# 52  DEBLENDED_AT_EDGE STATIONARY MOVED BINNED1 INT...
# 53  PSF_FLUX_INTERP DEBLENDED_AT_EDGE INTERP_CENTE...
# 54  PSF_FLUX_INTERP DEBLEND_NOPEAK DEBLENDED_AT_ED...
# 55  DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY BI...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

## Want Color-magnitude plot ##
pairDf = crossDf[['u_g', 'g_z', 'g_r', 'g_i', 'r_i', 'r_z', 'modelMag_r',]]
p1 = sns.pairplot(pairDf, corner = False)
p1.map_diag(sns.histplot)
# Out:
# Text(0.5, 1.0, 'Pairplot for SD_MDG set')

# %%
# x_vars = ["u_g", "g_z", "modelMag_r", "petroRad_r"]
x_vars = ["u_g", "g_z"]
y_vars = ["modelMag_r"]
g = sns.PairGrid(pairDf, x_vars=x_vars, y_vars=y_vars, height = 3)
# g.map_diag(sns.histplot, color=".3")
g.map_offdiag(sns.scatterplot)
g.add_legend()
plt.gca().invert_yaxis()
# plt.gca().invert_xaxis()
# g.axes[0, 0].set_ylim(modMagr_lim[::-1])
# g.axes[0, 0].set_xlim(ug_lim[::-1])
# g.axes[0, 0].set_xlim(ug_lim[::-1])

# g.axes[0, 1].set_xlim(gz_lim[::-1])
