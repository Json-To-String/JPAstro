# %%
# from astroquery.sdss import SDSS
# from astropy import coordinates as coords
# co = coords.SkyCoord('0h8m05.63s +14d50m23.3s')
# result = SDSS.query_region(co)
# print(result[:5])
import pandas as pd

# %%
import SciServer.CasJobs as CasJobs # query with CasJobs, the primary database for the SDSS
import SciServer.SkyServer as SkyServer # show individual objects through SkyServer
import SciServer.SciDrive
import warnings
warnings.filterwarnings('ignore')

# %%
testQuery = "SELECT TOP 100 \
 p.objID, p.ra, p.dec, \
 p.modelMag_r, \
 p.modelMag_u - p.modelMag_g as u_g, \
 p.modelMag_g - p.modelMag_z as g_z, \
 p.modelMag_g - p.modelMag_r as g_r, \
 p.modelMag_g - p.modelMag_i as g_i, \
 p.modelMag_r - p.modelMag_i as r_i, \
 p.modelMag_r - p.modelMag_z as r_z, \
 p.petroRad_r, p.flags, dbo.fPhotoFlagsN(p.flags) as flag_text \
FROM\
 photoObj as p \
JOIN dbo.fGetNearbyObjEq(49.9467, 41.5131, 45) as N ON N.objID = p.objID \
WHERE\
 p.modelMag_r > -14.3*(p.modelMag_g - p.modelMag_z) + 37 \
 and p.modelMag_r > -14.3*(p.modelMag_g - p.modelMag_z) + 46 \
 and p.type = 3"
#  and p.flags & dbo.fPhotoFlags('MANYPETRO') = 0
#  and p.flags & dbo.fPhotoFlags('TOO_FEW_GOOD_DETECTIONS ') = 0
#  and p.flags & dbo.fPhotoFlags('BAD_MOVING_FIT_CHILD ') = 0
#  and p.flags & dbo.fPhotoFlags('PEAKS_TOO_CLOSE ') = 0
#  and p.flags & dbo.fPhotoFlags('NODEBLEND_MOVING') = 0"
testQuery
# Out:
# 'SELECT TOP 100  p.objID, p.ra, p.dec,  p.modelMag_r,  p.modelMag_u - p.modelMag_g as u_g,  p.modelMag_g - p.modelMag_z as g_z,  p.modelMag_g - p.modelMag_r as g_r,  p.modelMag_g - p.modelMag_i as g_i,  p.modelMag_r - p.modelMag_i as r_i,  p.modelMag_r - p.modelMag_z as r_z,  p.petroRad_r, p.flags, dbo.fPhotoFlagsN(p.flags) as flag_text FROM photoObj as p JOIN dbo.fGetNearbyObjEq(49.9467, 41.5131, 45) as N ON N.objID = p.objID WHERE p.modelMag_r > -14.3*(p.modelMag_g - p.modelMag_z) + 37  and p.modelMag_r > -14.3*(p.modelMag_g - p.modelMag_z) + 46  and p.type = 3'

# %%
CasJobs.executeQuery(testQuery, "dr16")
# Out:
#                   objID         ra        dec  modelMag_r       u_g       g_z  \
# 0   1237661122388166413  50.051934  41.103875    22.35309  3.968340  2.418644
# 1   1237661083199408996  50.041297  41.084135    23.79697  2.098536  3.507635
# 2   1237661083199408505  50.048718  41.084989    22.55978  0.500900  2.059986
# 3   1237661083199407882  50.048636  41.090652    24.01087 -0.176594  1.733398
# 4   1237661083199342871  50.017554  41.076307    21.83455  0.543772  2.434597
# ..                  ...        ...        ...         ...       ...       ...
# 95  1237661055281987781  50.165361  41.059796    22.70486 -0.810167  3.511297
# 96  1237661055281987786  50.150907  41.069623    25.67938 -0.360065  4.795816
# 97  1237661055281987785  50.150143  41.070215    24.61443 -0.208506  4.821493
# 98  1237661055281987784  50.157742  41.065132    22.48851  1.409597  2.713932
# 99  1237661055281987783  50.154963  41.067112    24.67794 -0.731174  5.269539
#
#          g_r       g_i       r_i       r_z  petroRad_r            flags  \
# 0   0.769152  1.770256  1.001104  1.649492    2.969374  281543964754176
# 1   0.219826  1.697176  1.477350  3.287809    2.969919  281543964623104
# 2   1.163574  1.507071  0.343496  0.896412    2.969919  281543964623616
# 3   0.530088  2.301363  1.771275  1.203310    2.969919  105622104178960
# 4   1.080433  1.956509  0.876076  1.354164    1.593828  105656464048728
# ..       ...       ...       ...       ...         ...              ...
# 95  2.471962  3.569426  1.097464  1.039335    0.958847  105622139703572
# 96 -0.550659  0.086740  0.637400  5.346476    2.969862  316728372236564
# 97  0.478140  0.699514  0.221375  4.343353    0.314875  316728372236564
# 98  0.707228  0.848068  0.140841  2.006704    1.405629  105553419960668
# 99  0.584392  0.811899  0.227507  4.685146    4.583963  457465860591892
#
#                                             flag_text
# 0   TOO_FEW_GOOD_DETECTIONS STATIONARY BINNED1 INT...
# 1   TOO_FEW_GOOD_DETECTIONS STATIONARY BINNED1 NOP...
# 2   TOO_FEW_GOOD_DETECTIONS STATIONARY BINNED1 MAN...
# 3   DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY BI...
# 4   DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY BA...
# ..                                                ...
# 95  DEBLEND_NOPEAK DEBLENDED_AT_EDGE STATIONARY BI...
# 96  TOO_FEW_GOOD_DETECTIONS DEBLENDED_AT_EDGE STAT...
# 97  TOO_FEW_GOOD_DETECTIONS DEBLENDED_AT_EDGE STAT...
# 98  DEBLEND_NOPEAK DEBLENDED_AT_EDGE BINNED1 DEBLE...
# 99  TOO_FEW_GOOD_DETECTIONS PSF_FLUX_INTERP DEBLEN...
#
# [100 rows x 13 columns]

# %%
df_phot = pd.DataFrame()
for index,query in enumerate(querylist):
    print('Executing query', index, 'of', len(atlas3d)-1)
    df = CasJobs.executeQuery(query, "dr16")
    df = df.assign(host_galaxy = atlas3d['galaxy'][index], host_distance= atlas3d['distance'][index], host_ra = atlas3d['RA'][index], host_dec = atlas3d['DEC'][index])
    data = [df_phot, df]
    df_phot = pd.concat(data, ignore_index = True, sort=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 df_phot = pd.DataFrame()
# ----> 2 for index,query in enumerate(querylist):
#       3     print('Executing query', index, 'of', len(atlas3d)-1)
#       4     df = CasJobs.executeQuery(query, "dr16")
#
# NameError: name 'querylist' is not defined
